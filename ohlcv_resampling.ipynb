# %%
# we are importing the necessary libaries 
from datetime import datetime, timedelta

import pandas as pd
from openbb import obb
# Out:
# /Users/Sugi/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# extracting data
obb.user.credentials.fmp_api_key = "JI198J9ADpdcD2yJ4kd8Zl0RAP1goenk"
df_daily = obb.equity.price.historical(symbol="spy", provider="fmp")
df = df_daily.to_df()
# Ensure the index is datetime
df.index = pd.to_datetime(df.index)

# Resample to weekly data (e.g., OHLC)
df_weekly = df.resample('W').agg({
    'open': 'first',
    'high': 'max',
    'low': 'min',
    'close': 'last',
    'volume': 'sum'  # or 'mean' based on preference
})

df_daily.to_df()
# Out:
#               open    high     low   close    volume      vwap  adj_close  \
# date
# 2024-06-17  542.08  548.53  541.61  547.10  55909364  544.8300     540.23
# 2024-06-18  547.16  548.62  546.73  548.49  41376417  547.7500     541.60
# 2024-06-20  549.44  550.12  545.18  547.00  70328226  547.9350     540.13
# 2024-06-21  544.40  545.65  543.02  544.51  64513900  544.3950     539.40
# 2024-06-24  544.33  546.95  542.62  542.74  45528700  544.1600     537.65
# ...            ...     ...     ...     ...       ...       ...        ...
# 2025-06-10  600.22  603.47  599.09  603.08  66247000  601.4650     603.08
# 2025-06-11  604.19  605.06  599.27  601.36  73658225  602.4700     601.36
# 2025-06-12  600.01  603.75  599.52  603.75  64129003  601.7575     603.75
# 2025-06-13  598.50  601.85  595.48  597.00  89506000  598.2075     597.00
# 2025-06-16  600.40  604.45  600.22  602.68  79984125  601.9375     602.68
#
#             unadjusted_volume  change  change_percent
# date
# 2024-06-17         55909364.0    5.02        0.009261
# 2024-06-18         41376417.0    1.33        0.002431
# 2024-06-20         70328226.0   -2.44       -0.004441
# 2024-06-21         64513900.0    0.11        0.000202
# 2024-06-24         45528700.0   -1.59       -0.002921
# ...                       ...     ...             ...
# 2025-06-10         66247000.0    2.86        0.004765
# 2025-06-11         73658225.0   -2.83       -0.004684
# 2025-06-12         64129003.0    3.74        0.006233
# 2025-06-13         89506000.0   -1.50       -0.002506
# 2025-06-16         79984125.0    2.28        0.003798
#
# [250 rows x 10 columns]
