# %%
# we are importing the necessary libaries 
from datetime import datetime, timedelta

import pandas as pd
from openbb import obb
# Out:
# /Users/Sugi/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
obb.user.credentials.fmp_api_key = "JI198J9ADpdcD2yJ4kd8Zl0RAP1goenk"
df_daily = obb.equity.price.historical(symbol="spy", provider="fmp")
df = df_daily.to_df()
# Summary statistics
df[['open', 'high', 'low', 'close', 'volume']].describe()
# Out:
#              open        high         low       close        volume
# count  250.000000  250.000000  250.000000  250.000000  2.500000e+02
# mean   572.941800  576.296320  569.278400  573.058640  5.801321e+07
# std     24.714518   23.221271   25.669675   24.496007  2.963271e+07
# min    489.190000  521.700000  481.800000  496.480000  2.604871e+07
# 25%    555.147500  559.430000  551.622500  555.375000  3.948770e+07
# 50%    573.890000  576.370000  570.310000  573.920000  5.011830e+07
# 75%    595.650000  597.772500  590.692500  594.465000  6.817863e+07
# max    611.540000  613.230000  609.560000  612.930000  2.566114e+08

# %%
import matplotlib.pyplot as plt

df[['close', 'open']].plot(figsize=(12, 6), title="Open vs Close Price Over Time")
plt.ylabel("Price")
plt.grid()
plt.show()
